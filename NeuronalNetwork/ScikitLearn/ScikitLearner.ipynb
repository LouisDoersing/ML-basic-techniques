# %%
# !pip install ucimlrepo
# !pip install scikit-learn

# %%
import pandas as pd
from sklearn.neural_network import MLPClassifier, MLPRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error
from matplotlib import pyplot as plt
import numpy as np
from sklearn.preprocessing import MinMaxScaler

# %%
real_estate = pd.read_csv("Real_estate_valuation_data_set.csv", sep=";")
print(real_estate.head())
real_estate.shape

#Secure, that every entry is numeric
for col in real_estate.columns:
    real_estate[col] = pd.to_numeric(real_estate[col].astype(str).str.replace(',', '.'), errors='coerce')
# Out:
#    No X1 transaction date X2 house age X3 distance to the nearest MRT station  \
# 0   1            2012,917           32                               84,87882
# 1   2            2012,917         19,5                               306,5947
# 2   3            2013,583         13,3                               561,9845
# 3   4            2013,500         13,3                               561,9845
# 4   5            2012,833            5                               390,5684
#
#    X4 number of convenience stores X5 latitude X6 longitude  \
# 0                               10    24,98298    121,54024
# 1                                9    24,98034    121,53951
# 2                                5    24,98746    121,54391
# 3                                5    24,98746    121,54391
# 4                                5    24,97937    121,54245
#
#   Y house price of unit area
# 0                       37,9
# 1                       42,2
# 2                       47,3
# ...

# %%
#Extract Features (X) and labels (y)
X = real_estate.iloc[:,1:-1]
#print(X.head())
y = real_estate.iloc[:,-1]
#print(y.head())


#Test into Test and Train 
x_train, x_test, y_train, y_test = train_test_split(X, y, random_state = 42)
print(y_test.head())
# Out:
# 358    45.1
# 350    42.3
# 373    52.2
# 399    37.3
# 369    22.8
# Name: Y house price of unit area, dtype: float64

# %%
#Initialize Neuronal Network
network = MLPRegressor(hidden_layer_sizes = (100, 100), max_iter=300, activation="relu")

# %%
#fit the Network to Training Data 
network.fit(x_train, y_train)
# Out:
# MLPRegressor(hidden_layer_sizes=(100, 100), max_iter=300)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
#predict with Test Data 
print(x_test)
predicted_values = network.predict(x_test)


#Calculate MSE
mse = mean_squared_error(y_test, predicted_values)
print(f"MSE: {mse}")

mae = mean_absolute_error(y_test, predicted_values)
print(f"MAE: {mae}")
# Out:
#      X1 transaction date  X2 house age  \
# 358             2013.167           1.1
# 350             2013.000          13.2
# 373             2013.083           0.0
# 399             2012.917          12.7
# 369             2012.667          20.2
# ..                   ...           ...
# 63              2013.583           2.6
# 261             2013.167          16.2
# 297             2012.833          34.9
# 113             2013.333          14.8
# 248             2013.000          19.0
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 358                                193.5845                                6
# 350                                492.2313                                5
# 373                                274.0144                                1
# 399                                170.1289                                1
# 369                               2185.1280                                3
# ...

# %%
#Create Test cases
house = [2013.0, 2, 830.1289, 8, 24.67371, 121.83059]
columns = ['X1 transaction date', 'X2 house age', 'X3 distance to the nearest MRT station', 'X4 number of convenience stores', 'X5 latitude', 'X6 longitude']
house_df = pd.DataFrame([house], columns=columns)
y_pred = network.predict(house_df)
print(y_pred)
# Out:
# [34.5308181]
